# %%
import main
main.main("between", 50, 0, 3, 0, 0)
# Out:
#  36%|███▌      | 18/50 [00:00<00:00, 339.51it/s]
# -----------------------------------------
# Running demands
# tf
# -218461.58324600355
# vi
# 109232.84322609752
# nt
# 109233.25267824356
# Sum of edv is 4.512658337538596
# order_ratio
# 1.000020656530409
# ----------------------
# -----------------------------------------
# Running demands
# tf
# 6.894170925428625
# vi
# 3.4785810904577374
# nt
# 3.567527675186284
# Sum of edv is 13.940279691072647
# order_ratio
# 0
# ----------------------
# -----------------------------------------
# Running demands
# tf
# 82798.61546896951
# vi
# -41396.5288314824
# nt
# -41397.12891113362
# Sum of edv is 4.957726353488397
# order_ratio
# 1.0000598805088297
# ----------------------
# -----------------------------------------
# Running demands
# tf
# -26515.023789950123
# vi
# 13254.41499497008
# nt
# 13241.946884501609
# Sum of edv is -18.66191047843313
# order_ratio
# 0.9992961759858761
# ----------------------
# ...
