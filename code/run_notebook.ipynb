# %%
import main
main.main("between", 50, 0, 3, 0, 0)
# Out:
#  46%|████▌     | 23/50 [00:00<00:00, 313.83it/s]
# -----------------------------------------
# Running demands
# tf
# -218461.58324600355
# vi
# 109232.84322609752
# nt
# 109233.12429172639
# Sum of edv is 4.384271820366848
# ----------------------
# -----------------------------------------
# Running demands
# tf
# 6.894316461868584
# vi
# 3.415068811737001
# nt
# 5.5353927101241425
# Sum of edv is 15.844777983729728
# ----------------------
# -----------------------------------------
# Running demands
# tf
# 82798.61559154495
# vi
# -41396.580966738635
# nt
# -41391.46471672773
# Sum of edv is 10.569908078585286
# ----------------------
# -----------------------------------------
# Running demands
# tf
# -26509.41150626156
# vi
# 13254.425607491052
# nt
# 13258.718275509193
# Sum of edv is 3.732376738684252
# ----------------------
# -----------------------------------------
# Running demands
# tf
# -28012.834828186198
# vi
# 14004.766478722333
# nt
# 14013.85118993395
# ...
