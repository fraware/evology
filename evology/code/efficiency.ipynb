# %%
#!/usr/bin/env python3

import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
 
# Import the data
df = pd.read_csv("/Users/aymericvie/Documents/GitHub/evology/evology/data/run_data.csv")
print(df)

df.plot(x="Gen", y = ["TotalTime"],
        kind="line", figsize=(15, 6))
plt.show()

df.plot(x="Gen", y = ['TimeA', 'TimeB', 'TimeC', 'TimeD', 'TimeE', 'TimeF', 'TimeG'],
        kind="line", figsize=(15, 6))
plt.show()
# Out:
#       Unnamed: 0     Gen   Price     Mismatch  Dividends  RDividend  \
# 0              0     0.0   97.91 -1567.211893   0.004029  -0.700704
# 1              1     1.0   98.33 -1665.449170   0.004046   0.662900
# 2              2     2.0   98.39 -4968.686110   0.004023  -0.907530
# 3              3     3.0   97.77  4648.061637   0.004055   1.240504
# 4              4     4.0   97.62 -3882.037870   0.004059   0.168101
# ...          ...     ...     ...          ...        ...        ...
# 4974        4974  4974.0  112.12  1332.108710   0.004261   0.732820
# 4975        4975  4975.0  111.92   706.521462   0.004289   1.015852
# 4976        4976  4976.0  112.18 -1073.843437   0.004303   0.523062
# 4977        4977  4977.0  113.17  4497.277300   0.004350   1.732405
# 4978        4978  4978.0  114.44   525.873001   0.004327  -0.855855
#
#             Volume  Rep        Pos+          Pos-  ...  Spoils     TimeA  \
# 0     7.476260e+05  0.0  50000000.0  0.000000e+00  ...     0.0  0.000080
# 1     1.158490e+06  0.0  50000000.0  0.000000e+00  ...     0.0  0.000054
# 2     7.052332e+05  0.0  50000000.0  0.000000e+00  ...     0.0  0.000054
# 3     7.119457e+05  0.0  50000000.0  0.000000e+00  ...     0.0  0.000054
# 4     1.064246e+06  0.0  50000000.0  0.000000e+00  ...     0.0  0.000054
# ...            ...  ...         ...           ...  ...     ...       ...
# 4974  1.002633e+06  0.0  50000000.0  1.635760e+06  ...     0.0  0.000055
# 4975  1.425170e+06  0.0  50000000.0  1.594346e+06  ...     0.0  0.000055
# 4976  8.343272e+05  0.0  50000000.0  1.562583e+06  ...     0.0  0.000055
# 4977  1.081030e+06  0.0  50000000.0  1.566959e+06  ...     0.0  0.000055
# 4978  8.661807e+05  0.0  50000000.0  1.610001e+06  ...     0.0  0.000055
#
#          TimeB         TimeC     TimeD     TimeE     TimeF     TimeG  \
# 0     0.000034  1.670000e-07  0.000203  0.001508  0.000265  0.000658
# 1     0.000034  1.897080e-04  0.000207  0.001327  0.000264  0.000618
# 2     0.000034  2.101670e-04  0.000205  0.001327  0.000271  0.000622
# 3     0.000034  1.311250e-04  0.000206  0.001520  0.000279  0.000619
# 4     0.000034  1.295840e-04  0.000202  0.001316  0.000267  0.000618
# ...        ...           ...       ...       ...       ...       ...
# 4974  0.000035  1.172500e-04  0.000212  0.001335  0.000269  0.000665
# 4975  0.000035  1.175830e-04  0.000224  0.001331  0.000261  0.000662
# 4976  0.000035  1.219580e-04  0.000216  0.001332  0.000272  0.000665
# 4977  0.000035  1.242080e-04  0.000215  0.001526  0.000270  0.000685
# 4978  0.000036  1.151250e-04  0.000216  0.001529  0.000271  0.000670
#
#       TotalTime  PerSpoils
# 0      0.002749        0.0
# 1      0.002693        0.0
# 2      0.002723        0.0
# 3      0.002842        0.0
# 4      0.002621        0.0
# ...         ...        ...
# 4974   0.002688        0.0
# 4975   0.002686        0.0
# 4976   0.002697        0.0
# 4977   0.002910        0.0
# 4978   0.002892        0.0
#
# [4979 rows x 55 columns]
