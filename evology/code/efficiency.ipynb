# %%
#!/usr/bin/env python3

import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
 
# Import the data
df = pd.read_csv("/Users/aymericvie/Documents/GitHub/evology/evology/data/run_data.csv")
print(df)

df.plot(x="Gen", y = ["TotalTime"],
        kind="line", figsize=(15, 6))
plt.show()

df.plot(x="Gen", y = ['TimeA', 'TimeB', 'TimeC', 'TimeD', 'TimeE', 'TimeF', 'TimeG'],
        kind="line", figsize=(15, 6))
plt.show()
# Out:
#        Unnamed: 0      Gen   Price     Mismatch  Dividends  RDividend  \
# 0               0      0.0  101.63  1855.306114   0.004227   0.000864
# 1               1      1.0  101.37  1363.949437   0.004209  -0.663304
# 2               2      2.0  101.08  -742.783970   0.004204  -0.192732
# 3               3      3.0  100.92 -2491.738898   0.004207   0.084543
# 4               4      4.0  100.88  -936.022887   0.004177  -1.105828
# ...           ...      ...     ...          ...        ...        ...
# 19974       19974  19974.0  443.95   667.445238   0.017547  -0.112627
# 19975       19975  19975.0  444.76   506.975187   0.017633   0.769121
# 19976       19976  19976.0  446.00   -57.179223   0.017510  -1.112581
# 19977       19977  19977.0  445.08  -803.683211   0.017336  -1.581935
# 19978       19978  19978.0  443.06   695.638946   0.017510   1.582394
#
#               Volume  Rep        Pos+          Pos-  ...     TimeD     TimeE  \
# 0      163744.121289  0.0  25000000.0  0.000000e+00  ...  0.000110  0.000703
# 1      332321.093755  0.0  25000000.0  0.000000e+00  ...  0.000109  0.000700
# 2      245115.010996  0.0  25000000.0  0.000000e+00  ...  0.000108  0.000701
# 3      238579.918076  0.0  25000000.0  0.000000e+00  ...  0.000109  0.000699
# 4      258137.298305  0.0  25000000.0  0.000000e+00  ...  0.000102  0.000670
# ...              ...  ...         ...           ...  ...       ...       ...
# 19974  484690.602399  0.0  25000000.0  9.498667e+05  ...  0.000100  0.000662
# 19975  491502.203371  0.0  25000000.0  9.251274e+05  ...  0.000099  0.000663
# 19976  343208.271236  0.0  25000000.0  1.037775e+06  ...  0.000098  0.000667
# 19977  475543.071890  0.0  25000000.0  1.070645e+06  ...  0.000100  0.000664
# 19978  342745.411600  0.0  25000000.0  9.924316e+05  ...  0.000101  0.000760
#
#           TimeF     TimeG  TotalTime  PerSpoils  NT_MonReturns  VI_MonReturns  \
# 0      0.000145  0.000424   0.001999        0.0       0.007686       0.007398
# 1      0.000150  0.000367   0.002053        0.0       0.020955       0.020630
# 2      0.000150  0.000368   0.002000        0.0       0.021332       0.021027
# 3      0.000150  0.000358   0.001997        0.0       0.017135       0.016878
# 4      0.000141  0.000355   0.001920        0.0       0.016055       0.015825
# ...         ...       ...        ...        ...            ...            ...
# 19974  0.000144  0.000353   0.001901        0.0       0.007385      -0.003696
# 19975  0.000146  0.000356   0.001901        0.0       0.013015       0.002583
# 19976  0.000144  0.000370   0.001917        0.0       0.013262       0.005075
# 19977  0.000145  0.000363   0.001911        0.0       0.006854       0.008071
# 19978  0.000147  0.000356   0.002003        0.0       0.006388       0.009365
#
#        TF_MonReturns  AvgMonReturn
# 0           0.007261      0.007438
# 1           0.018781      0.020031
# 2           0.019170      0.020419
# 3           0.015481      0.016429
# 4           0.014555      0.015416
# ...              ...           ...
# 19974      -0.005217     -0.000728
# 19975       0.002232      0.005788
# 19976       0.004963      0.007652
# 19977       0.008045      0.007672
# 19978       0.009468      0.008451
#
# [19979 rows x 59 columns]

# %%
df.plot(x="Gen", y = ['TimeA', 'TimeB', 'TimeC', 'TimeD', 'TimeE', 'TimeF', 'TimeG'],
        kind="line", figsize=(15, 6), ylim = (0,0.002))
plt.show()

sumE = df['TimeE'].sum()
print(sumE)

totalRT = df['TotalTime'].sum()
print(totalRT)

print(100 * sumE / totalRT)
# Out:
# 14.154644907998915
# 39.44987249799873
# 35.88007770802547
