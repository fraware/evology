# %%
import pandas as pd
import numpy as np

''' Under adaptation '''

standard_coord = pd.read_csv("/Users/aymericvie/Documents/GitHub/evology/evology/research/TransferStatus/GainMatrixSingle/data/neutral_combined/static_standard.csv")
NT_bump_coord = pd.read_csv("/Users/aymericvie/Documents/GitHub/evology/evology/research/TransferStatus/GainMatrixSingle/data/neutral_combined/static_NT_bump.csv")
VI_bump_coord = pd.read_csv("/Users/aymericvie/Documents/GitHub/evology/evology/research/TransferStatus/GainMatrixSingle/data/neutral_combined/static_VI_bump.csv")
TF_bump_coord = pd.read_csv("/Users/aymericvie/Documents/GitHub/evology/evology/research/TransferStatus/GainMatrixSingle/data/neutral_combined/static_TF_bump.csv")


# ''' Under static '''

# standard_coord = pd.read_csv("/Users/aymericvie/Documents/GitHub/evology/evology/research/TransferStatus/GainMatrixSingle/data/neutral_static/static_standard.csv")
# NT_bump_coord = pd.read_csv("/Users/aymericvie/Documents/GitHub/evology/evology/research/TransferStatus/GainMatrixSingle/data/neutral_static/static_NT_bump.csv")
# VI_bump_coord = pd.read_csv("/Users/aymericvie/Documents/GitHub/evology/evology/research/TransferStatus/GainMatrixSingle/data/neutral_static/static_VI_bump.csv")
# TF_bump_coord = pd.read_csv("/Users/aymericvie/Documents/GitHub/evology/evology/research/TransferStatus/GainMatrixSingle/data/neutral_static/static_TF_bump.csv")

# %%
''' Gain matrix estimation without outliers '''
np.set_printoptions(suppress=True)
margin = 3

# standard_coord = pd.read_csv("/Users/aymericvie/Documents/GitHub/evology/evology/research/TransferStatus/GainMatrixSingle/data/static_standard.csv")

clean_standard_coord = pd.DataFrame()

new_standard_coord = pd.DataFrame()
new_standard_coord = standard_coord[np.abs(standard_coord['NT_MonReturns']-standard_coord['NT_MonReturns'].mean()) <= (margin*standard_coord['NT_MonReturns'].std())]
standard_coord_NT_Return = new_standard_coord['NT_MonReturns'].mean()
clean_standard_coord['NT_MonReturns'] = 100 * new_standard_coord['NT_MonReturns']

new_standard_coord = pd.DataFrame()
new_standard_coord = standard_coord[np.abs(standard_coord['VI_MonReturns']-standard_coord['VI_MonReturns'].mean()) <= (margin*standard_coord['VI_MonReturns'].std())]
standard_coord_VI_Return = new_standard_coord['VI_MonReturns'].mean()
clean_standard_coord['VI_MonReturns'] = 100 * new_standard_coord['VI_MonReturns']

new_standard_coord = pd.DataFrame()
new_standard_coord = standard_coord[np.abs(standard_coord['TF_MonReturns']-standard_coord['TF_MonReturns'].mean()) <= (margin*standard_coord['TF_MonReturns'].std())]
standard_coord_TF_Return = new_standard_coord['TF_MonReturns'].mean()
clean_standard_coord['TF_MonReturns'] = 100 * new_standard_coord['TF_MonReturns']

print(standard_coord_NT_Return, standard_coord_VI_Return, standard_coord_TF_Return)

clean_NT_bump_coord = pd.DataFrame()

new_NT_bump_coord = pd.DataFrame()
new_NT_bump_coord = NT_bump_coord[np.abs(NT_bump_coord['NT_MonReturns']-NT_bump_coord['NT_MonReturns'].mean()) <= (margin*NT_bump_coord['NT_MonReturns'].std())]
NT_bump_NT_Return = new_NT_bump_coord['NT_MonReturns'].mean()
clean_NT_bump_coord['NT_MonReturns'] = 100 * new_NT_bump_coord['NT_MonReturns']

new_NT_bump_coord = pd.DataFrame()
new_NT_bump_coord = NT_bump_coord[np.abs(NT_bump_coord['VI_MonReturns']-NT_bump_coord['VI_MonReturns'].mean()) <= (margin*NT_bump_coord['VI_MonReturns'].std())]
NT_bump_VI_Return = new_NT_bump_coord['VI_MonReturns'].mean()
clean_NT_bump_coord['VI_MonReturns'] = 100 * new_NT_bump_coord['VI_MonReturns']

new_NT_bump_coord = pd.DataFrame()
new_NT_bump_coord = NT_bump_coord[np.abs(NT_bump_coord['TF_MonReturns']-NT_bump_coord['TF_MonReturns'].mean()) <= (margin*NT_bump_coord['TF_MonReturns'].std())]
NT_bump_TF_Return = new_NT_bump_coord['TF_MonReturns'].mean()
clean_NT_bump_coord['TF_MonReturns'] = 100 * new_NT_bump_coord['TF_MonReturns']

print(NT_bump_NT_Return, NT_bump_VI_Return, NT_bump_TF_Return)


clean_VI_bump_coord = pd.DataFrame()

new_VI_bump_coord = pd.DataFrame()
new_VI_bump_coord = VI_bump_coord[np.abs(VI_bump_coord['NT_MonReturns']-VI_bump_coord['NT_MonReturns'].mean()) <= (margin*VI_bump_coord['NT_MonReturns'].std())]
VI_bump_NT_Return = new_VI_bump_coord['NT_MonReturns'].mean()
clean_VI_bump_coord['NT_MonReturns'] = 100 * new_VI_bump_coord['NT_MonReturns']

new_VI_bump_coord = pd.DataFrame()
new_VI_bump_coord = VI_bump_coord[np.abs(VI_bump_coord['VI_MonReturns']-VI_bump_coord['VI_MonReturns'].mean()) <= (margin*VI_bump_coord['VI_MonReturns'].std())]
VI_bump_VI_Return = new_VI_bump_coord['VI_MonReturns'].mean()
clean_VI_bump_coord['VI_MonReturns'] = 100 * new_VI_bump_coord['VI_MonReturns']

new_VI_bump_coord = pd.DataFrame()
new_VI_bump_coord = VI_bump_coord[np.abs(VI_bump_coord['TF_MonReturns']-VI_bump_coord['TF_MonReturns'].mean()) <= (margin*VI_bump_coord['TF_MonReturns'].std())]
VI_bump_TF_Return = new_VI_bump_coord['TF_MonReturns'].mean()
clean_VI_bump_coord['TF_MonReturns'] = 100 * new_VI_bump_coord['TF_MonReturns']

print(VI_bump_NT_Return, VI_bump_VI_Return, VI_bump_TF_Return)


clean_TF_bump_coord = pd.DataFrame()
new_TF_bump_coord = pd.DataFrame()
new_TF_bump_coord = TF_bump_coord[np.abs(TF_bump_coord['NT_MonReturns']-TF_bump_coord['NT_MonReturns'].mean()) <= (margin*TF_bump_coord['NT_MonReturns'].std())]
TF_bump_NT_Return = new_TF_bump_coord['NT_MonReturns'].mean()
clean_TF_bump_coord['NT_MonReturns'] = 100 * new_TF_bump_coord['NT_MonReturns']


new_TF_bump_coord = pd.DataFrame()
new_TF_bump_coord = TF_bump_coord[np.abs(TF_bump_coord['VI_MonReturns']-TF_bump_coord['VI_MonReturns'].mean()) <= (margin*TF_bump_coord['VI_MonReturns'].std())]
TF_bump_VI_Return = new_TF_bump_coord['VI_MonReturns'].mean()
clean_TF_bump_coord['VI_MonReturns'] = 100 * new_TF_bump_coord['VI_MonReturns']

new_TF_bump_coord = pd.DataFrame()
new_TF_bump_coord = TF_bump_coord[np.abs(TF_bump_coord['TF_MonReturns']-TF_bump_coord['TF_MonReturns'].mean()) <= (margin*TF_bump_coord['TF_MonReturns'].std())]
TF_bump_TF_Return = new_TF_bump_coord['TF_MonReturns'].mean()
clean_TF_bump_coord['TF_MonReturns'] = 100 * new_TF_bump_coord['TF_MonReturns']

print(TF_bump_NT_Return, TF_bump_VI_Return, TF_bump_TF_Return)
# Out:
# 0.0037002422017078707 0.005929640062277613 0.0009052157716401528
# 0.005660219857159052 0.005783108737481289 0.011890492308196231
# 0.00033634481095108404 0.000347349430804147 -0.008585376929194824
# 0.0016264095756719603 -0.0016550863078206423 0.00063836394094884

# %%
import statsmodels as stats 
import scipy 
import pingouin as pg

def write_signif(res):
    if res['p-val'][0] < 0.01:
        # signif = str.maketrans('***')
        signif = '^{***}'
    elif res['p-val'][0] < 0.05:
        # signif = str.maketrans('**')
        signif = '^{**}'
    elif res['p-val'][0] < 0.1:
        # signif = str.maketrans('*')
        signif = '^{*}'
    elif res['p-val'][0] >= 0.1:
        signif = ''
    return signif

''' 
Null hypothesis: means are equal 
Alternative hypothesis" means are different 

For p-value >= alpha: fail to reject null hypothesis
For p-value < alpha: reject H0 and accept HA
'''

print('--NT ROW--')

res = pg.ttest(1/h * (clean_NT_bump_coord['NT_MonReturns'] - clean_standard_coord['NT_MonReturns']), 0, correction=False, confidence=0.95)
display(res)
signif00 = write_signif(res)
ci00 = res['CI95%'][0]
print(1/h * (clean_NT_bump_coord['NT_MonReturns'] - clean_standard_coord['NT_MonReturns']).mean())


res = pg.ttest(1/h  * (clean_VI_bump_coord['NT_MonReturns'] - clean_standard_coord['NT_MonReturns']), 0, correction=False, confidence=0.95)
display(res)
signif01 = write_signif(res)
ci01 = res['CI95%'][0]
print(1/h * (clean_VI_bump_coord['NT_MonReturns'] - clean_standard_coord['NT_MonReturns']).mean())

res = pg.ttest(1/h * (clean_TF_bump_coord['NT_MonReturns'] - clean_standard_coord['NT_MonReturns']), 0, correction=False, confidence=0.95)
display(res)
signif02 = write_signif(res)
ci02 = res['CI95%'][0]
print(1/h * (clean_TF_bump_coord['NT_MonReturns'] - clean_standard_coord['NT_MonReturns']).mean())

print('--VI ROW--')

res = pg.ttest(1/h * (clean_NT_bump_coord['VI_MonReturns'] - clean_standard_coord['VI_MonReturns']), 0, correction=False, confidence=0.95)
display(res)
signif10 = write_signif(res)
ci10 = res['CI95%'][0]
print(1/h * (clean_NT_bump_coord['VI_MonReturns'] - clean_standard_coord['VI_MonReturns']).mean())


res = pg.ttest(1/h  * (clean_VI_bump_coord['VI_MonReturns'] - clean_standard_coord['VI_MonReturns']), 0, correction=False, confidence=0.95)
display(res)
signif11 = write_signif(res)
ci11 = res['CI95%'][0]
print(1/h * (clean_VI_bump_coord['VI_MonReturns'] - clean_standard_coord['VI_MonReturns']).mean())

res = pg.ttest(1/h * (clean_TF_bump_coord['VI_MonReturns'] - clean_standard_coord['VI_MonReturns']), 0, correction=False, confidence=0.95)
display(res)
signif12 = write_signif(res)
ci12 = res['CI95%'][0]
print(1/h * (clean_TF_bump_coord['VI_MonReturns'] - clean_standard_coord['VI_MonReturns']).mean())

print('--TF ROW--')

res = pg.ttest(1/h * (clean_NT_bump_coord['TF_MonReturns'] - clean_standard_coord['TF_MonReturns']), 0, correction=False, confidence=0.95)
display(res)
signif20 = write_signif(res)
ci20 = res['CI95%'][0]
print(1/h * (clean_NT_bump_coord['TF_MonReturns'] - clean_standard_coord['TF_MonReturns']).mean())


res = pg.ttest(1/h  * (clean_VI_bump_coord['TF_MonReturns'] - clean_standard_coord['TF_MonReturns']), 0, correction=False, confidence=0.95)
display(res)
signif21 = write_signif(res)
ci21 = res['CI95%'][0]
print(1/h * (clean_VI_bump_coord['TF_MonReturns'] - clean_standard_coord['TF_MonReturns']).mean())

res = pg.ttest(1/h * (clean_TF_bump_coord['TF_MonReturns'] - clean_standard_coord['TF_MonReturns']), 0, correction=False, confidence=0.95)
display(res)
signif22 = write_signif(res)
ci22 = res['CI95%'][0]
print(1/h * (clean_TF_bump_coord['TF_MonReturns'] - clean_standard_coord['TF_MonReturns']).mean())
# Out:
# --NT ROW--
#                T  dof alternative     p-val              CI95%   cohen-d  \
# T-test  0.352305   18   two-sided  0.728701  [-112.15, 157.34]  0.080824
#
#          BF10     power
# T-test  0.251  0.062868
# 22.594919243361407
#                T  dof alternative     p-val             CI95%   cohen-d  \
# T-test -0.800062   18   two-sided  0.434108  [-165.16, 74.06]  0.183547
#
#          BF10     power
# T-test  0.316  0.117987
# -45.55068134810057
#                T  dof alternative     p-val             CI95%   cohen-d  BF10  \
# T-test -0.406263   19   two-sided  0.689089  [-163.3, 110.21]  0.090843  0.25
#
#            power
# T-test  0.067249
# -26.545057613259644
# --VI ROW--
#                T  dof alternative     p-val              CI95%   cohen-d  \
# T-test  0.127346   15   two-sided  0.900358  [-153.32, 172.81]  0.031837
#
#          BF10     power
# T-test  0.257  0.051635
# 9.742466612595685
# ...

# %%
np.set_printoptions(suppress=True)
GainMatrix = np.zeros((3,3))
h = 2/256

''' It is mutliplied by 1/h by finite difference, and by 100 to obtain percentages '''

GainMatrix[0,0] = round(100/h * (NT_bump_NT_Return - standard_coord_NT_Return),3)
GainMatrix[0,1] = round(100/h * (VI_bump_NT_Return - standard_coord_NT_Return),3)
GainMatrix[0,2] = round(100/h * (TF_bump_NT_Return - standard_coord_NT_Return),3)

GainMatrix[1,0] = round(100/h * (NT_bump_VI_Return - standard_coord_VI_Return),3)
GainMatrix[1,1] = round(100/h * (VI_bump_VI_Return - standard_coord_VI_Return),3)
GainMatrix[1,2] = round(100/h * (TF_bump_VI_Return - standard_coord_VI_Return),3)

GainMatrix[2,0] = round(100/h * (NT_bump_TF_Return - standard_coord_TF_Return),3)
GainMatrix[2,1] = round(100/h * (VI_bump_TF_Return - standard_coord_TF_Return),3)
GainMatrix[2,2] = round(100/h * (TF_bump_TF_Return - standard_coord_TF_Return),3)

# print(GainMatrix)

# %%
from tabulate import tabulate
from texttable import Texttable
import latextable

rows = [['', 'NT', 'VI', 'TF'],
        ['NT', str(GainMatrix[0,0]) + str(signif00), str(GainMatrix[0,1]) + str(signif01), str(GainMatrix[0,2]) + str(signif02)],
        ['VI', str(GainMatrix[1,0]) + str(signif10), str(GainMatrix[1,1]) + str(signif11), str(GainMatrix[1,2]) + str(signif12)],
        ['TF', str(GainMatrix[2,0]) + str(signif20), str(GainMatrix[2,1]) + str(signif21), str(GainMatrix[2,2]) + str(signif22)]]

table = Texttable()
table.set_cols_align(["C"] * 4)
table.set_deco(Texttable.HEADER | Texttable.VLINES | Texttable.BORDER)
table.add_rows(rows)


print('\nTexttable Table:')
print(table.draw())
print(latextable.draw_latex(table, 
        caption="Gain matrix at the equal wealth coordinates. Significance is showed for p-value inferior to 0.01 (***), 0.05 (**) and 0.1 (*)."))
# Out:
# Texttable Table:
# +----+---------+----------+---------+
# |    |   NT    |    VI    |   TF    |
# +====+=========+==========+=========+
# | NT | 25.088  | -43.058  | -26.545 |
# | VI | -1.876  | -71.453  | -97.084 |
# | TF | 140.612 | -121.480 | -3.416  |
# +----+---------+----------+---------+
# \begin{table}
# 	\begin{center}
# 		\begin{tabular}{|C|C|C|C|}
# 			\hline
# 			 & NT & VI & TF \\
# 			\hline
# 			NT & 25.088 & -43.058 & -26.545 \\
# 			VI & -1.876 & -71.453 & -97.084 \\
# 			TF & 140.612 & -121.480 & -3.416 \\
# 			\hline
# 		\end{tabular}
# 	\end{center}
# 	\caption{Gain matrix at the equal wealth coordinates. Significance is showed for p-value inferior to 0.01 (***), 0.05 (**) and 0.1 (*).}
# \end{table}

# %%
from tabulate import tabulate
from texttable import Texttable
import latextable

rows = [['', 'NT', 'VI', 'TF'],
        ['NT', str(ci00), str(ci01), str(ci02)],
        ['VI', str(ci10), str(ci11), str(ci12)],
        ['TF', str(ci20), str(ci21), str(ci22)]]

table = Texttable()
table.set_cols_align(["C"] * 4)
table.set_deco(Texttable.HEADER | Texttable.VLINES | Texttable.BORDER)
table.add_rows(rows)


print('\nTexttable Table:')
print(table.draw())
print(latextable.draw_latex(table, caption="95\% Confidence intervals of the gain matrix entries at the equal wealth coordinates"))
# Out:
# Texttable Table:
# +----+-------------------+-------------------+-------------------+
# |    |        NT         |        VI         |        TF         |
# +====+===================+===================+===================+
# | NT | [-112.15  157.34] | [-165.16   74.06] | [-163.3   110.21] |
# | VI | [-153.32  172.81] | [-217.59   70.89] | [-478.09  148.9 ] |
# | TF | [-72.89 270.06]   | [-341.06  192.54] | [-99.51 118.85]   |
# +----+-------------------+-------------------+-------------------+
# \begin{table}
# 	\begin{center}
# 		\begin{tabular}{|C|C|C|C|}
# 			\hline
# 			 & NT & VI & TF \\
# 			\hline
# 			NT & [-112.15  157.34] & [-165.16   74.06] & [-163.3   110.21] \\
# 			VI & [-153.32  172.81] & [-217.59   70.89] & [-478.09  148.9 ] \\
# 			TF & [-72.89 270.06] & [-341.06  192.54] & [-99.51 118.85] \\
# 			\hline
# 		\end{tabular}
# 	\end{center}
# 	\caption{95\% Confidence intervals of the gain matrix entries at the equal wealth coordinates}
# \end{table}
