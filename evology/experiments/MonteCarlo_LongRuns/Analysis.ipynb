# %%
''' Modules imports '''

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
''' Data imports and preprocessing'''

PathsNT = pd.read_csv("/Users/aymericvie/Documents/GitHub/evology/evology/experiments/MonteCarlo_LongRuns/PathsNT.csv")
PathsVI = pd.read_csv("/Users/aymericvie/Documents/GitHub/evology/evology/experiments/MonteCarlo_LongRuns/PathsVI.csv")
PathsTF = pd.read_csv("/Users/aymericvie/Documents/GitHub/evology/evology/experiments/MonteCarlo_LongRuns/PathsTF.csv")

del PathsNT['Unnamed: 0']
del PathsVI['Unnamed: 0']
del PathsTF['Unnamed: 0']

# %%
Time = range(PathsNT.shape[1])

print(PathsNT)
# Out:
#            0          1          2          3          4          5  \
# 0  36.422223  36.423694  36.430503  36.273527  36.143846  36.050192
# 1  42.966225  42.926557  42.897081  42.919954  42.827895  42.899961
# 2  52.460180  52.456773  52.447998  52.582609  52.563023  52.649192
# 3  36.553647  36.515929  36.509128  36.543708  36.295651  36.156975
# 4  36.877696  36.846350  36.826312  36.790301  36.788176  36.811307
#
#            6          7          8          9  ...      12527      12528  \
# 0  36.217751  36.486656  36.405938  36.426698  ...  65.081151  65.054368
# 1  42.687414  42.919298  42.943351  42.880524  ...  86.997214  87.069612
# 2  52.889893  52.586669  52.877633  52.838143  ...  86.084643  85.377551
# 3  36.308630  36.581440  36.608070  36.621324  ...  59.694492  59.890858
# 4  36.649459  36.689158  36.757568  36.793227  ...  31.806323  31.899176
#
#        12529      12530      12531      12532      12533      12534  \
# 0  64.917258  64.852340  64.657707  64.561330  64.486237  64.414254
# 1  86.606675  87.285604  85.611770  85.653404  86.985416  84.352742
# 2  85.197976  84.803118  84.693291  84.404386  84.426041  83.606976
# 3  60.073108  60.026375  60.218492  60.450152  60.331296  60.014752
# 4  32.018463  32.097577  32.127855  32.149169  32.213040  32.384076
#
#        12535      12536
# 0  64.531494  64.483384
# 1  83.717886  82.997117
# 2  82.519881  81.386587
# 3  60.176375  60.359667
# 4  32.465997  32.491262
#
# [5 rows x 12537 columns]

# %%
fig, axes = plt.subplots(nrows=3, ncols=1, sharex=True, sharey=True, figsize=(20,8))
plt.xlabel('Time (days)')
plt.ylabel('Wealth Share (%)')
plt.title('Wealth Share of strategies over time')
PathsNT.T.plot(legend=False, ax=axes[0])
axes[0].set_title('NT')
PathsVI.T.plot(legend=False, ax=axes[1])
axes[1].set_title('VI')
PathsTF.T.plot(legend=False, ax=axes[2])
axes[2].set_title('TF')

plt.show()
