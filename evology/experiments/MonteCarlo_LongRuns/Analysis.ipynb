# %%
''' Modules imports '''

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
''' Data imports and preprocessing'''

PathsNT = pd.read_csv("/Users/aymericvie/Documents/GitHub/evology/evology/experiments/MonteCarlo_LongRuns/PathsNT.csv")
PathsVI = pd.read_csv("/Users/aymericvie/Documents/GitHub/evology/evology/experiments/MonteCarlo_LongRuns/PathsVI.csv")
PathsTF = pd.read_csv("/Users/aymericvie/Documents/GitHub/evology/evology/experiments/MonteCarlo_LongRuns/PathsTF.csv")

del PathsNT['Unnamed: 0']
del PathsVI['Unnamed: 0']
del PathsTF['Unnamed: 0']

# %%
Time = range(PathsNT.shape[1])

print(PathsNT)
# Out:
#            0          1          2          3          4          5  \
# 0  43.049441  43.074929  43.089042  43.018475  43.092493  42.914546
# 1  46.792720  46.642439  46.757026  46.762028  46.700063  46.678598
# 2  36.941545  36.876372  36.774360  36.837346  36.532940  36.607716
# 3  41.053041  40.886030  40.978971  40.945406  40.929569  40.967256
# 4  41.692914  41.703413  41.614261  41.604225  41.578723  41.576495
# 5  37.180433  37.209886  37.020264  36.883859  37.194719  37.218478
# 6  46.260838  46.147487  46.243939  46.277413  46.264285  46.255588
# 7  50.100615  50.059853  49.908049  50.110516  50.057543  50.100559
# 8  41.295936  41.207186  41.245399  41.293939  40.990063  41.053742
# 9  43.547514  43.394232  43.786177  43.571013  43.720320  43.754891
#
#            6          7          8          9  ...       2447       2448  \
# 0  42.960201  43.049624  43.088989  43.091950  ...  42.228603  42.352418
# ...

# %%
fig, axes = plt.subplots(nrows=3, ncols=1, sharex=True, sharey=True, figsize=(20,8))
plt.xlabel('Time (days)')
plt.ylabel('Wealth Share (%)')
plt.title('Wealth Share of strategies over time')
PathsNT.T.plot(legend=False, ax=axes[0])
axes[0].set_title('NT')
PathsVI.T.plot(legend=False, ax=axes[1])
axes[1].set_title('VI')
PathsTF.T.plot(legend=False, ax=axes[2])
axes[2].set_title('TF')

plt.show()
