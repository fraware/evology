# %%
import sys
sys.path.insert(0, '/Users/aymericvie/Documents/GitHub/evology/evology/code/')
from main import *
pop, asset_supply = cr.CreatePop(100, 'extended', [1/3, 1/3, 1/3])
TF_strat = []
VI_strat = []
NT_strat = []

for ind in pop:
    if ind.type == 'tf':
        TF_strat.append(ind[0])
    if ind.type == 'vi': 
        VI_strat.append(ind.strategy)
    if ind.type == 'nt':
        NT_strat.append(ind.strategy)

plt.hist(TF_strat)
plt.show()
plt.hist(VI_strat)
plt.show()
plt.hist(NT_strat)
plt.show()
